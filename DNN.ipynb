# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import datasets
from pandas.plotting import parallel_coordinates
from sklearn.linear_model import LogisticRegression
# To evaluate our model
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

import tensorflow as tf
from tensorflow.python.keras.layers import Dense
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import to_categorical

# %%
sonar=pd.read_csv("/content/drive/MyDrive/selected topics/sonar.csv")
sonar.head()
# Out:
#    attribute_1  attribute_2  attribute_3  attribute_4  attribute_5  \
# 0       0.0200       0.0371       0.0428       0.0207       0.0954
# 1       0.0453       0.0523       0.0843       0.0689       0.1183
# 2       0.0262       0.0582       0.1099       0.1083       0.0974
# 3       0.0100       0.0171       0.0623       0.0205       0.0205
# 4       0.0762       0.0666       0.0481       0.0394       0.0590
#
#    attribute_6  attribute_7  attribute_8  attribute_9  attribute_10  ...  \
# 0       0.0986       0.1539       0.1601       0.3109        0.2111  ...
# 1       0.2583       0.2156       0.3481       0.3337        0.2872  ...
# 2       0.2280       0.2431       0.3771       0.5598        0.6194  ...
# 3       0.0368       0.1098       0.1276       0.0598        0.1264  ...
# 4       0.0649       0.1209       0.2467       0.3564        0.4459  ...
#
#    attribute_52  attribute_53  attribute_54  attribute_55  attribute_56  \
# 0        0.0027        0.0065        0.0159        0.0072        0.0167
# 1        0.0084        0.0089        0.0048        0.0094        0.0191
# 2        0.0232        0.0166        0.0095        0.0180        0.0244
# 3        0.0121        0.0036        0.0150        0.0085        0.0073
# 4        0.0031        0.0054        0.0105        0.0110        0.0015
#
#    attribute_57  attribute_58  attribute_59  attribute_60  Class
# 0        0.0180        0.0084        0.0090        0.0032   Rock
# 1        0.0140        0.0049        0.0052        0.0044   Rock
# 2        0.0316        0.0164        0.0095        0.0078   Rock
# 3        0.0050        0.0044        0.0040        0.0117   Rock
# 4        0.0072        0.0048        0.0107        0.0094   Rock
#
# [5 rows x 61 columns]

# %%
# sonar = sonar.batch(1)
X = sonar.copy()

labels=  X.pop('Class')

# Initialize the Label Encoder.
le = LabelEncoder()

# Encode the categories
sonar['Class_enc'] = le.fit_transform(sonar['Class'])

y=sonar['Class_enc']

print(X)
print(y)
print(labels)
# Out:
#      attribute_1  attribute_2  attribute_3  attribute_4  attribute_5  \
# 0         0.0200       0.0371       0.0428       0.0207       0.0954
# 1         0.0453       0.0523       0.0843       0.0689       0.1183
# 2         0.0262       0.0582       0.1099       0.1083       0.0974
# 3         0.0100       0.0171       0.0623       0.0205       0.0205
# 4         0.0762       0.0666       0.0481       0.0394       0.0590
# ..           ...          ...          ...          ...          ...
# 203       0.0187       0.0346       0.0168       0.0177       0.0393
# 204       0.0323       0.0101       0.0298       0.0564       0.0760
# 205       0.0522       0.0437       0.0180       0.0292       0.0351
# 206       0.0303       0.0353       0.0490       0.0608       0.0167
# 207       0.0260       0.0363       0.0136       0.0272       0.0214
#
#      attribute_6  attribute_7  attribute_8  attribute_9  attribute_10  ...  \
# 0         0.0986       0.1539       0.1601       0.3109        0.2111  ...
# 1         0.2583       0.2156       0.3481       0.3337        0.2872  ...
# 2         0.2280       0.2431       0.3771       0.5598        0.6194  ...
# 3         0.0368       0.1098       0.1276       0.0598        0.1264  ...
# 4         0.0649       0.1209       0.2467       0.3564        0.4459  ...
# ..           ...          ...          ...          ...           ...  ...
# 203       0.1630       0.2028       0.1694       0.2328        0.2684  ...
# 204       0.0958       0.0990       0.1018       0.1030        0.2154  ...
# 205       0.1171       0.1257       0.1178       0.1258        0.2529  ...
# 206       0.1354       0.1465       0.1123       0.1945        0.2354  ...
# 207       0.0338       0.0655       0.1400       0.1843        0.2354  ...
#
#      attribute_51  attribute_52  attribute_53  attribute_54  attribute_55  \
# 0          0.0232        0.0027        0.0065        0.0159        0.0072
# 1          0.0125        0.0084        0.0089        0.0048        0.0094
# 2          0.0033        0.0232        0.0166        0.0095        0.0180
# 3          0.0241        0.0121        0.0036        0.0150        0.0085
# 4          0.0156        0.0031        0.0054        0.0105        0.0110
# ..            ...           ...           ...           ...           ...
# 203        0.0203        0.0116        0.0098        0.0199        0.0033
# 204        0.0051        0.0061        0.0093        0.0135        0.0063
# 205        0.0155        0.0160        0.0029        0.0051        0.0062
# 206        0.0042        0.0086        0.0046        0.0126        0.0036
# 207        0.0181        0.0146        0.0129        0.0047        0.0039
#
#      attribute_56  attribute_57  attribute_58  attribute_59  attribute_60
# 0          0.0167        0.0180        0.0084        0.0090        0.0032
# 1          0.0191        0.0140        0.0049        0.0052        0.0044
# 2          0.0244        0.0316        0.0164        0.0095        0.0078
# 3          0.0073        0.0050        0.0044        0.0040        0.0117
# 4          0.0015        0.0072        0.0048        0.0107        0.0094
# ..            ...           ...           ...           ...           ...
# 203        0.0101        0.0065        0.0115        0.0193        0.0157
# 204        0.0063        0.0034        0.0032        0.0062        0.0067
# 205        0.0089        0.0140        0.0138        0.0077        0.0031
# 206        0.0035        0.0034        0.0079        0.0036        0.0048
# 207        0.0061        0.0040        0.0036        0.0061        0.0115
#
# [208 rows x 60 columns]
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 203    0
# 204    0
# 205    0
# 206    0
# 207    0
# Name: Class_enc, Length: 208, dtype: int64
# 0      Rock
# 1      Rock
# 2      Rock
# 3      Rock
# 4      Rock
#        ...
# 203    Mine
# 204    Mine
# 205    Mine
# 206    Mine
# 207    Mine
# Name: Class, Length: 208, dtype: object

# %% [markdown]
# Feature selection

# %%
v_threshold = VarianceThreshold(threshold=0.008)
v_threshold.fit(X)
print(v_threshold.get_support())
allfeatures=v_threshold.get_support()
# Out:
# [False False False False False False False False  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True False False
#  False False False False False False False False False False False False]

# %%
selected_features=[]
j=1
for i in allfeatures:
  if(i==True):
    selected_features.append('attribute_' + str(j))
  j+=1

# print(selected_features)
# for i in selected_features:
#   print(sonar[i])
print(len(selected_features))
# Out:
# 38

# %%
columns=selected_features
df = pd.read_csv("/content/drive/MyDrive/selected topics/sonar.csv", usecols=selected_features)
# print(df.head())
x2=df.copy()
df['Class_enc'] = le.fit_transform(sonar['Class'])

y2=df['Class_enc']

# print(X)
# print(y)

# %% [markdown]
# Data visualization for the selected features

# %%
sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(6, 3,sharey=False,sharex=False, figsize=(20,24))
x=0
for i in range(0,3):
  for j in range(0,6):
    if x>=18:
      break;
    # sns.relplot( y=sonar[selected_features[x]], hue="Class", data=sonar);
    sns.stripplot(x=sonar["Class"], y=sonar[selected_features[x]], data=sonar, ax=axes[j,i])
    x+=1
  if x>=18:
      break;

# %%
fig2, axes2 = plt.subplots(7, 3,sharey=False,sharex=False, figsize=(20,24))
for i in range(0,3):
  for j in range(0,7):
    if x>=len(selected_features):
      break;
    sns.stripplot(x=sonar["Class"], y=sonar[selected_features[x]], data=sonar, ax=axes2[j,i])
    x+=1
  if x>=len(selected_features):
      break;

# %% [markdown]
# Without feature selection

# %%
#stratify: split the dataset into train and test sets in a way that preserves the same proportions of examples in each class as observed in the original dataset.
#Setting random_state a fixed value will guarantee that same sequence of random numbers are generated each time the code is run

#using all features
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=2, stratify=y)

# %%
no_xRows=X_train.shape[0]
print(X_train.shape)
no_xColumns=X_train.shape[1]
no_yRows=y_train.shape[0]
# Out:
# (156, 60)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold

model = Sequential()
model.add(Dense(60, activation='relu', input_shape=(60,)))
model.add(Dense(40, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy' ,optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=20,verbose=1)
_, accuracy = model.evaluate(X_test, y_test, batch_size=no_xRows, verbose=2)
print(accuracy)
# Out:
# Epoch 1/20
# 5/5 [==============================] - 1s 5ms/step - loss: 0.6921 - accuracy: 0.5897
# Epoch 2/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.6218
# Epoch 3/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6862 - accuracy: 0.5513
# Epoch 4/20
# 5/5 [==============================] - 0s 7ms/step - loss: 0.6814 - accuracy: 0.5385
# Epoch 5/20
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6776 - accuracy: 0.5385
# Epoch 6/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6739 - accuracy: 0.5513
# Epoch 7/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6691 - accuracy: 0.5641
# Epoch 8/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6634 - accuracy: 0.5897
# Epoch 9/20
# 5/5 [==============================] - 0s 7ms/step - loss: 0.6572 - accuracy: 0.6154
# Epoch 10/20
# 5/5 [==============================] - 0s 8ms/step - loss: 0.6499 - accuracy: 0.6538
# Epoch 11/20
# 5/5 [==============================] - 0s 6ms/step - loss: 0.6428 - accuracy: 0.6731
# Epoch 12/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6350 - accuracy: 0.6731
# Epoch 13/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6246 - accuracy: 0.7051
# Epoch 14/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6188 - accuracy: 0.6859
# Epoch 15/20
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6055 - accuracy: 0.7115
# Epoch 16/20
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6003 - accuracy: 0.7628
# Epoch 17/20
# 5/5 [==============================] - 0s 6ms/step - loss: 0.5873 - accuracy: 0.7756
# Epoch 18/20
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5844 - accuracy: 0.7372
# Epoch 19/20
# 5/5 [==============================] - 0s 6ms/step - loss: 0.5693 - accuracy: 0.7885
# Epoch 20/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5697 - accuracy: 0.8077
# 1/1 - 0s - loss: 0.5387 - accuracy: 0.8654 - 296ms/epoch - 296ms/step
# 0.8653846383094788

# %%
model2 = Sequential()
model2.add(Dense(60, activation='relu', input_shape=(60,)))
model2.add(Dense(40, activation='relu'))
model2.add(Dense(1, activation='sigmoid'))
model2.compile(loss='binary_crossentropy' ,optimizer='adam', metrics=['accuracy'])
model2.fit(X_train, y_train, epochs=20,verbose=1)
_, accuracy = model2.evaluate(X_test, y_test, batch_size=no_xRows, verbose=2)
print(accuracy)
# Out:
# Epoch 1/20
# 5/5 [==============================] - 1s 5ms/step - loss: 0.6927 - accuracy: 0.5321
# Epoch 2/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6763 - accuracy: 0.5321
# Epoch 3/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6658 - accuracy: 0.5385
# Epoch 4/20
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6555 - accuracy: 0.6474
# Epoch 5/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6453 - accuracy: 0.6731
# Epoch 6/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6364 - accuracy: 0.6859
# Epoch 7/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6258 - accuracy: 0.6667
# Epoch 8/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6163 - accuracy: 0.6795
# Epoch 9/20
# 5/5 [==============================] - 0s 6ms/step - loss: 0.6081 - accuracy: 0.6795
# Epoch 10/20
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5974 - accuracy: 0.6987
# Epoch 11/20
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5871 - accuracy: 0.7051
# Epoch 12/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5768 - accuracy: 0.7244
# Epoch 13/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5659 - accuracy: 0.7308
# Epoch 14/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5569 - accuracy: 0.7244
# Epoch 15/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5464 - accuracy: 0.7500
# Epoch 16/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5380 - accuracy: 0.7500
# Epoch 17/20
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5249 - accuracy: 0.7821
# Epoch 18/20
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5171 - accuracy: 0.7692
# Epoch 19/20
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5056 - accuracy: 0.7949
# Epoch 20/20
# 5/5 [==============================] - 0s 6ms/step - loss: 0.4949 - accuracy: 0.7692
# 1/1 - 0s - loss: 0.4798 - accuracy: 0.7692 - 223ms/epoch - 223ms/step
# 0.7692307829856873

# %% [markdown]
# With feature selection

# %%
#using some features
df_train, df_test, dfy_train, dfy_test = train_test_split(x2, y2, test_size=0.25, random_state=2, stratify=y2)

# %%
model3 = Sequential()
model3.add(Dense(38, activation='relu', input_shape=(38,)))
model3.add(Dense(40, activation='relu'))
model3.add(Dense(1, activation='sigmoid'))
model3.compile(loss='binary_crossentropy' ,optimizer='adam', metrics=['accuracy'])
model3.fit(df_train, dfy_train, epochs=25,verbose=1)
_, accuracy = model3.evaluate(df_test, dfy_test, batch_size=no_xRows, verbose=2)
print(accuracy)
# Out:
# Epoch 1/25
# 5/5 [==============================] - 1s 3ms/step - loss: 0.7086 - accuracy: 0.4679
# Epoch 2/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6900 - accuracy: 0.5449
# Epoch 3/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6734 - accuracy: 0.6154
# Epoch 4/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6659 - accuracy: 0.6026
# Epoch 5/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6591 - accuracy: 0.6026
# Epoch 6/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6515 - accuracy: 0.6154
# Epoch 7/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6440 - accuracy: 0.6731
# Epoch 8/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6354 - accuracy: 0.6859
# Epoch 9/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6273 - accuracy: 0.7051
# Epoch 10/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6177 - accuracy: 0.6923
# Epoch 11/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6092 - accuracy: 0.7179
# Epoch 12/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5998 - accuracy: 0.7115
# Epoch 13/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5917 - accuracy: 0.7308
# Epoch 14/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5842 - accuracy: 0.7372
# Epoch 15/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5766 - accuracy: 0.7436
# Epoch 16/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5663 - accuracy: 0.7436
# Epoch 17/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5573 - accuracy: 0.7564
# Epoch 18/25
# 5/5 [==============================] - 0s 7ms/step - loss: 0.5458 - accuracy: 0.7756
# Epoch 19/25
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5365 - accuracy: 0.7885
# Epoch 20/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5279 - accuracy: 0.7692
# Epoch 21/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5187 - accuracy: 0.7949
# Epoch 22/25
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5090 - accuracy: 0.7949
# Epoch 23/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4987 - accuracy: 0.8013
# Epoch 24/25
# 5/5 [==============================] - 0s 6ms/step - loss: 0.4913 - accuracy: 0.8013
# Epoch 25/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4820 - accuracy: 0.7949
# 1/1 - 0s - loss: 0.4293 - accuracy: 0.8846 - 181ms/epoch - 181ms/step
# 0.8846153616905212

# %%
model4 = Sequential()
model4.add(Dense(60, activation='relu', input_shape=(38,)))
model4.add(Dense(40, activation='relu'))
model4.add(Dense(20, activation='relu'))
model4.add(Dense(20, activation='softmax'))
model4.add(Dense(1, activation='sigmoid'))
model4.compile(loss='binary_crossentropy' ,optimizer='adam', metrics=['accuracy'])
model4.fit(df_train, dfy_train, epochs=25,verbose=1)
_, accuracy = model4.evaluate(df_test, dfy_test, batch_size=no_xRows, verbose=2)
print(accuracy)
# Out:
# Epoch 1/25
# 5/5 [==============================] - 1s 3ms/step - loss: 0.6981 - accuracy: 0.4679
# Epoch 2/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6954 - accuracy: 0.4679
# Epoch 3/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6934 - accuracy: 0.4679
# Epoch 4/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6914 - accuracy: 0.4808
# Epoch 5/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6890 - accuracy: 0.7564
# Epoch 6/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6876 - accuracy: 0.6346
# Epoch 7/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6846 - accuracy: 0.5897
# Epoch 8/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6818 - accuracy: 0.5962
# Epoch 9/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6778 - accuracy: 0.5897
# Epoch 10/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6743 - accuracy: 0.5962
# Epoch 11/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6690 - accuracy: 0.6154
# Epoch 12/25
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6625 - accuracy: 0.6603
# Epoch 13/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6547 - accuracy: 0.6923
# Epoch 14/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6500 - accuracy: 0.7115
# Epoch 15/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6412 - accuracy: 0.7308
# Epoch 16/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6351 - accuracy: 0.7308
# Epoch 17/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6265 - accuracy: 0.7500
# Epoch 18/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6216 - accuracy: 0.7179
# Epoch 19/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6142 - accuracy: 0.7564
# Epoch 20/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6094 - accuracy: 0.7821
# Epoch 21/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6054 - accuracy: 0.7628
# Epoch 22/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5984 - accuracy: 0.7949
# Epoch 23/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5958 - accuracy: 0.7885
# Epoch 24/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5855 - accuracy: 0.8269
# Epoch 25/25
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5876 - accuracy: 0.8205
# 1/1 - 0s - loss: 0.5513 - accuracy: 0.9038 - 147ms/epoch - 147ms/step
# 0.9038461446762085
